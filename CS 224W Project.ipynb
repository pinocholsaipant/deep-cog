# %%
# !pip install nilearn
# Out:
# ...
#      |████████████████████████████████| 10.0 MB 16.0 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 63.4 MB/s
# ...

# %%
from nilearn.datasets import (fetch_openneuro_dataset_index,
                              fetch_openneuro_dataset, select_from_index)

_, urls = fetch_openneuro_dataset_index(dataset_version='ds000171')

# data_dir, _ = fetch_openneuro_dataset(urls=urls)

print(urls)

# %%
pip install deepdish
# Out:
# ...
#      |████████████████████████████████| 4.3 MB 5.3 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 124 kB 32.1 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numba
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 30.9 MB/s
# ...
#      |████████████████████████████████| 26.3 MB 22.7 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data_dir = '/data/notebook_files/BrainGNN_Pytorch/data/ABIDE_pcp/cpac/filt_noglobal/raw'

# %%
correlation matrix/ edge weights

-incorporate more detailed temporal data?
-directed edges

dimensionality reduction
-use PCA instead of top-k pooling?

MEGABRAIN
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# SyntaxError: invalid syntax
